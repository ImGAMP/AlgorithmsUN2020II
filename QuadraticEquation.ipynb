# %% [markdown]
# <a href="https://colab.research.google.com/github/ImGAMP/AlgorithmsUN2020II/blob/master/QuadraticEquation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import cmath

# %% [markdown]
# #First
# Plot the following functions in a x range that include that include the vertex and the roots (if there are roots):
#
# *   x^2
# *   (x-1)^2
# *   x^2 – 1
# *   x^2+ 1

# %%
# Createing vectors X and Y 
x = np.linspace(-2, 2, 100) 
y = x ** 2
  
fig = plt.figure(figsize = (12, 7)) 
# Create the plot 
plt.plot(x, y, alpha = 0.4, label ='Y = X²', 
         color ='red',  
         linewidth = 2, marker ='D',  
         markersize = 5, markerfacecolor ='blue', 
         markeredgecolor ='blue') 
  
# Add a title 
plt.title('Equation plot x^2') 
  
# Add X and y Label 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

  
  
# Add a grid 
plt.grid(alpha =.6, linestyle ='--') 
  
# Add a Legend 
plt.legend() 
  
# Show the plot 
plt.show()

# %%
# Createing vectors X and Y 
x = np.linspace(-10, 10, 100) 
y = (x-1) ** 2
  
fig = plt.figure(figsize = (12, 7)) 
# Create the plot 
plt.plot(x, y, alpha = 0.4, label ='Y = X²', 
         color ='red',  
         linewidth = 2, marker ='D',  
         markersize = 5, markerfacecolor ='blue', 
         markeredgecolor ='blue') 
  
# Add a title 
plt.title('Equation plot (x-1)^2') 
  
# Add X and y Label 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

  
  
# Add a grid 
plt.grid(alpha =.6, linestyle ='--') 
  
# Add a Legend 
plt.legend() 
  
# Show the plot 
plt.show()

# %%
# Creating vectors X and Y 
x = np.linspace(-2, 2, 100) 
y = x ** 2 - 1
  
fig = plt.figure(figsize = (12, 7)) 
# Create the plot 
plt.plot(x, y, alpha = 0.4, label ='Y = X²', 
         color ='red',  
         linewidth = 2, marker ='D',  
         markersize = 5, markerfacecolor ='blue', 
         markeredgecolor ='blue') 
  
# Add a title 
plt.title('Equation plot x^2 -1') 
  
# Add X and y Label 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
  
  
# Add a grid 
plt.grid(alpha =.6, linestyle ='--') 
  
# Add a Legend 
plt.legend() 
  
# Show the plot 
plt.show()

# %%
# Creating vectors X and Y 
x = np.linspace(-2, 2, 100) 
y = x ** 2 + 1
  
fig = plt.figure(figsize = (12, 7)) 
# Create the plot 
plt.plot(x, y, alpha = 0.4, label ='Y = X²', 
         color ='red',  
         linewidth = 2, marker ='D',  
         markersize = 5, markerfacecolor ='blue', 
         markeredgecolor ='blue') 
  
# Add a title 
plt.title('Equation plot x^2 + 1 ') 
  
# Add X and y Label 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
  
  
# Add a grid 
plt.grid(alpha =.6, linestyle ='--') 
  
# Add a Legend 
plt.legend() 
  
# Show the plot 
plt.show()

# %% [markdown]
# --------

# %% [markdown]
# #Second
# Apply the Classic and Po Shen Loh ‘s methods for solving the following quadratic equations
# *   x^2 = 0
# *   (x-1)^2 = 0
# *   x^2 – 1 =0
# *   x^2+ 1 =0

# %%
def solveClassic (a, b, c):
  d = (b**2) - (4*a*c)

  # find two solutions
  sol1 = (-b-cmath.sqrt(d))/(2*a)
  sol2 = (-b+cmath.sqrt(d))/(2*a)

  print('The solution with classic method are {0} and {1}'.format(sol1,sol2))

def solvePo (a , b, c):
  b= b/a
  c = c/a
  d = (b**2)/4 - c

  sol1 = -(b/2) + cmath.sqrt(d)
  sol2 = -(b/2) - cmath.sqrt(d)

  print('The solution with Quadratic Formula Po-Shen Lohare are {0} and {1}'.format(sol1,sol2))

# %%
print("Function: x^2")
solveClassic(1,0,0)
solvePo(1,0,0)
# Out:
# Function: x^2
# The solution with classic method are 0j and 0j
# The solution with Quadratic Formula Po-Shen Lohare are 0j and (-0+0j)

# %%
print("Function: x^2 -2x + 1")
solveClassic(1,-2,1)
solvePo(1,-2,1)
# Out:
# Function: x^2 -2x + 1
# The solution with classic method are (1+0j) and (1+0j)
# The solution with Quadratic Formula Po-Shen Lohare are (1+0j) and (1+0j)

# %%
print("Function: x^2 -1")
solveClassic(1,0,-1)
solvePo(1,0,-1)
# Out:
# Function: x^2 -1
# The solution with classic method are (-1+0j) and (1+0j)
# The solution with Quadratic Formula Po-Shen Lohare are (1+0j) and (-1+0j)

# %%
print("Function: x^2 +1")
solveClassic(1,0,1)
solvePo(1,0,1)
# Out:
# Function: x^2 +1
# The solution with classic method are -1j and 1j
# The solution with Quadratic Formula Po-Shen Lohare are 1j and (-0-1j)

# %% [markdown]
# ________

# %% [markdown]
# #Third
# to plot the newton fractals for the corresponding complex quadratic polynomials
# * z^2
# * (z-1)^2
# * z^2 – 1
# * z^2+ 1

# %%
def solvePoL (a , b, c):
  b= b/a
  c = c/a
  d = (b**2)/4 - c

  sol1 = -(b/2) + cmath.sqrt(d)
  sol2 = -(b/2) - cmath.sqrt(d)

  return (sol1,sol2)

# %% [markdown]
# ###*Newton Fractal f(x)=Z^2*

# %%
def f(z):
    return z ** 2 

def df(z):
    return 2 * z

def newton_set1(a,b,c,z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    pol = solvePoL(a,b,c)
    r1 = pol[0]
    r2 = pol[1]

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(a=0,b=0,c=0,z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256,text =''):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(a,b,c,z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title(text)
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
display1(a=1,b=0,c=0,zoom=1,text = "Newton Fractal f(x)=Z^2")
display1(a=1,b=0,c=0,zoom=10,text = "Newton Fractal f(x)=Z^2")
display1(a=1,b=0,c=0,zoom=100,text = "Newton Fractal f(x)=Z^2")
display1(a=1,b=0,c=0,zoom=1/10,text = "Newton Fractal f(x)=Z^2")
display1(a=1,b=0,c=0,zoom=1/100,text = "Newton Fractal f(x)=Z^2")
display1(a=1,b=0,c=0,zoom=1/1000,text = "Newton Fractal f(x)=Z^2")
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -5.0 , -5.0 ) to ( 5.0 , 5.0 )
# Z region from ( -50.0 , -50.0 ) to ( 50.0 , 50.0 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ###*Newton Fractal f(x)=(Z-1)^2*

# %%
def f(z):
    return (z-1) ** 2

def df(z):
    return 2 * z - 2

def newton_set1(a,b,c,z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    pol = solvePoL(a,b,c)
    r1 = pol[0]
    r2 = pol[1]

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(a=0,b=0,c=0,z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256,text =''):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(a,b,c,z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title(text)
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
display1(a=1,b=-2,c=1,zoom=1,text = "Newton Fractal f(x)=(Z-1)^2")
display1(a=1,b=-2,c=1,zoom=10,text = "Newton Fractal f(x)=(Z-1)^2")
display1(a=1,b=-2,c=1,zoom=100,text = "Newton Fractal f(x)=(Z-1)^2")
display1(a=1,b=-2,c=1,zoom=1/10,text = "Newton Fractal f(x)=(Z-1)^2")
display1(a=1,b=-2,c=1,zoom=1/100,text = "Newton Fractal f(x)=(Z-1)^2")
display1(a=1,b=-2,c=1,zoom=1/1000,text = "Newton Fractal f(x)=(Z-1)^2")
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -5.0 , -5.0 ) to ( 5.0 , 5.0 )
# Z region from ( -50.0 , -50.0 ) to ( 50.0 , 50.0 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ###*Newton Fractal f(x)=Z^2-1*

# %%
def f(z):
    return z ** 2 -1

def df(z):
    return 2 * z

def newton_set1(a,b,c,z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    pol = solvePoL(a,b,c)
    r1 = pol[0]
    r2 = pol[1]

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(a=0,b=0,c=0,z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256,text =''):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(a,b,c,z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title(text)
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
display1(a=1,b=0,c=-1,zoom=1,text = "Newton Fractal f(x)=Z^2-1")
display1(a=1,b=0,c=-1,zoom=10,text = "Newton Fractal f(x)=Z^2-1")
display1(a=1,b=0,c=-1,zoom=100,text = "Newton Fractal f(x)=Z^2-1")
display1(a=1,b=0,c=-1,zoom=1/10,text = "Newton Fractal f(x)=Z^2-1")
display1(a=1,b=0,c=-1,zoom=1/100,text = "Newton Fractal f(x)=Z^2-1")
display1(a=1,b=0,c=-1,zoom=1/1000,text = "Newton Fractal f(x)=Z^2-1")
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -5.0 , -5.0 ) to ( 5.0 , 5.0 )
# Z region from ( -50.0 , -50.0 ) to ( 50.0 , 50.0 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ________

# %% [markdown]
# ###*Newton Fractal f(x)=Z^2+1*

# %%
def f(z):
    return z ** 2 +1

def df(z):
    return 2 * z

def newton_set1(a,b,c,z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    pol = solvePoL(a,b,c)
    r1 = pol[0]
    r2 = pol[1]

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(a=0,b=0,c=0,z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256,text =''):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(a,b,c,z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title(text)
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
display1(a=1,b=0,c=1,zoom=1,text = "Newton Fractal f(x)=Z^2+1")
display1(a=1,b=0,c=1,zoom=10,text = "Newton Fractal f(x)=Z^2+1")
display1(a=1,b=0,c=1,zoom=100,text = "Newton Fractal f(x)=Z^2+1")
display1(a=1,b=0,c=1,zoom=1/10,text = "Newton Fractal f(x)=Z^2+1")
display1(a=1,b=0,c=1,zoom=1/100,text = "Newton Fractal f(x)=Z^2+1")
display1(a=1,b=0,c=1,zoom=1/1000,text = "Newton Fractal f(x)=Z^2+1")
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -5.0 , -5.0 ) to ( 5.0 , 5.0 )
# Z region from ( -50.0 , -50.0 ) to ( 50.0 , 50.0 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# #Fourth
# Plot the Newton iterates for points on the positive and negative axes for the complex quadratic polynomials in 3. Give an interpretation of the results.

# %% [markdown]
# ###*$Z^{2}$*

# %%
def f(z):
    return z ** 2 

def df(z):
    return 2 * z

print("Positive axe")    
z=10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z:10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

print("Negative axe")    
z=-10.0 - 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 -10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# Positive axe
# Negative axe

# %% [markdown]
# ###*$(Z-1)^{2}$*

# %%
def f(z):
    return (z-1) ** 2 

def df(z):
    return 2 * z - 2 

print("Positive axe")    
z=10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z:10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

print("Negative axe")    
z=-10.0 - 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 -10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# Positive axe
# Negative axe

# %% [markdown]
# ###*$Z^{2} -1 $*

# %%
def f(z):
    return z ** 2 -1

def df(z):
    return 2 * z

print("Positive axe")    
z=10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z:10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

print("Negative axe")    
z=-10.0 - 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 -10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# Positive axe
# Negative axe

# %% [markdown]
# ###*$Z^{2} +1 $*

# %%
def f(z):
    return z ** 2 +1

def df(z):
    return 2 * z

print("Positive axe")    
z=10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z:10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

print("Negative axe")    
z=-10.0 - 10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 -10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# Positive axe
# Negative axe

# %% [markdown]
# #Fifth
# Plot he Newton iterates for points on the diagonals in the four quadrants and 0.0 + 0.0j for the complex quadratic polynomials in 3. Give an interpretation of the results.

# %% [markdown]
# ###*$Z^{2}$*

# %%
def f(z):
    return z ** 2 

def df(z):
    return 2 * z

text= ("Newton iterates form z=10.0 + 0.0j")    
print(text)
z=10.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

text = "Newton iterates form z=0.0 + 10.0j"
print(text)    
z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
text= ("Newton iterates form z=-10.0 + 0.0j")    
print(text)
z=-10.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

text = "Newton iterates form z=0.0 - 10.0j"
print(text)    
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

text = "Newton iterates form z=0.0 + 0.0j"
print(text)    
z=-0.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# Newton iterates form z=10.0 + 0.0j
# Newton iterates form z=0.0 + 10.0j
# Newton iterates form z=-10.0 + 0.0j
# Newton iterates form z=0.0 - 10.0j
# Newton iterates form z=0.0 + 0.0j
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-115-dc838c403db9> in <module>()
#      83 for k in range(50):
#      84   dz = df(z)
# ---> 85   z = z - f(z) / dz # Newton iteration
#      86   r.append(np.real(z))
#      87   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# ###*$(Z-1)^{2}$*

# %%
def f(z):
    return (z-1) ** 2 
def df(z):
    return 2 * z -2
 
text= ("Newton iterates form z=10.0 + 0.0j")    
print(text)
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

text = "Newton iterates form z=0.0 + 10.0j"
print(text)    
z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
text= ("Newton iterates form z=-10.0 + 0.0j")    
print(text)
z=-10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

text = "Newton iterates form z=0.0 - 10.0j"
print(text)    
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

text = "Newton iterates form z=0.0 + 0.0j"
print(text)    
z=-0.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# Newton iterates form z=10.0 + 0.0j
# Newton iterates form z=0.0 + 10.0j
# Newton iterates form z=-10.0 + 0.0j
# Newton iterates form z=0.0 - 10.0j
# Newton iterates form z=0.0 + 0.0j

# %% [markdown]
# ###*$Z^{2} -1 $*

# %%
def f(z):
    return z ** 2 -1

def df(z):
    return 2 * z

text= ("Newton iterates form z=10.0 + 0.0j")    
print(text)
z=10.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

text = "Newton iterates form z=0.0 + 10.0j"
print(text)    
z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
text= ("Newton iterates form z=-10.0 + 0.0j")    
print(text)
z=-10.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

text = "Newton iterates form z=0.0 - 10.0j"
print(text)    
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

text = "Newton iterates form z=0.0 + 0.0j"
print(text)    
z=-0.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# Newton iterates form z=10.0 + 0.0j
# Newton iterates form z=0.0 + 10.0j
# Newton iterates form z=-10.0 + 0.0j
# Newton iterates form z=0.0 - 10.0j
# Newton iterates form z=0.0 + 0.0j
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-113-12dc11e21db1> in <module>()
#      83 for k in range(50):
#      84   dz = df(z)
# ---> 85   z = z - f(z) / dz # Newton iteration
#      86   r.append(np.real(z))
#      87   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# ###*$Z^{2} +1 $*

# %%
def f(z):
    return z ** 2 + 1

def df(z):
    return 2 * z

text= ("Newton iterates form z=10.0 + 0.0j")    
print(text)
z=10.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

text = "Newton iterates form z=0.0 + 10.0j"
print(text)    
z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
text= ("Newton iterates form z=-10.0 + 0.0j")    
print(text)
z=-10.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

text = "Newton iterates form z=0.0 - 10.0j"
print(text)    
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

text = "Newton iterates form z=0.0 + 0.0j"
print(text)    
z=-0.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title(text)
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# Newton iterates form z=10.0 + 0.0j
# Newton iterates form z=0.0 + 10.0j
# Newton iterates form z=-10.0 + 0.0j
# Newton iterates form z=0.0 - 10.0j
# Newton iterates form z=0.0 + 0.0j
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-114-9a6abce4e41f> in <module>()
#      83 for k in range(50):
#      84   dz = df(z)
# ---> 85   z = z - f(z) / dz # Newton iteration
#      86   r.append(np.real(z))
#      87   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero
